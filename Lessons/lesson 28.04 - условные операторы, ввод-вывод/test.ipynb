# %%
45/5
# Out:
# 9.0

# %%
5555/5
# Out:
# 1111.0

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(start=-10, stop=10, num=100000000)
y = np.sin(x)

plt.plot(x, y)
plt.show()
